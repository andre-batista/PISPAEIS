# %%
import sys
sys.path.insert(1, '../../../../eispy2d/library/')
import casestudy as cst
import result as rst

# %% [markdown]
# # Experimento: Espalhador único e forte
#
# ## Dados do problema

# %%
mycase = cst.CaseStudy(import_filename='single.cst', 
                       import_filepath='./data/')
mycase.test.draw(show=True)
print(mycase.test)

# %% [markdown]
# ## Resultado dos indicadores de posição e função-objetivo

# %%
# mycase.boxplot([rst.POSITION_ERROR, rst.OBJECTIVE_FUNCTION], show=True)
# Out:
# ['zeta_s', 'zeta_p']

# %% [markdown]
# ## Resultado da estimativa de contraste

# %%
import numpy as np
x = np.zeros(30)
for n in range(30):
    x[n] = mycase.results[n].path[-1]
from matplotlib import pyplot as plt
plt.boxplot(x, labels=['CA'])
plt.xlabel('Algorithms')
plt.ylabel(r'Contrast ($\chi$)')
plt.grid()
plt.show()

# %% [markdown]
# ## Exemplo de uma das reconstruções obtidas

# %%
mycase.results[1].plot_map(show=True)

# %% [markdown]
# ## Conclusão
#
# O ponto fraco é a estimativa de contraste que não é tão boa. O ponto forte é o baixo erro de posição e a constância dos resultados (pouca variabilidade) que indica que, ao invés de 30 execuções, uma execução pode representar muito o problema.
