# %%
import sys
sys.path.insert(1, '../../../eispy2d/library/')
import casestudy as cst

# %%
import inputdata as ipt
test = ipt.InputData(import_filename='star.ipt',
                     import_filepath='../../../data/shape/star/')
print(test)
# Out:
# Input name: star.ipt
# Configuration file: star.cfg
# Images Resolution: 120x120
# Scattered field - measurement samples: 80
# Scattered field - source samples: 80
# Total field - measurement samples: 14400
# Total field - source samples: 80
# Noise level: 5.00%
# Relative Permit. map shape: 120x120
# Indicators: ['zeta_s', 'zeta_p']
# Degrees of Non-Linearity: 0.1161
# c:\Users\Andre\AppData\Local\Programs\Python\Python38\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.1, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
# c:\Users\Andre\AppData\Local\Programs\Python\Python38\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.1, the latest is 0.5.4.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
casestudy = cst.CaseStudy(import_filename='star.cst',
                          import_filepath='../../../data/shape/star/')
print(casestudy)
# Out:
# CASE STUDY
# Name: star.cst
# Method: lsm, osm, bim, csi, som
# Discretization: Richmond Method (40x40)
# Results: done
# Test: star.ipt
# Save stochastic runs? no
# Number of stochastic runs: 30
#
# star.ipt

# %%
casestudy.reconstruction(fontsize=15, show=True)

# %%
from tabulate import tabulate

table = [[casestudy.method[n].alias, casestudy.results[n].zeta_s[-1], 
          casestudy.results[n].zeta_p[-1]] for n in 
         range(len(casestudy.method))]

headers = ['Method', 'Shape error', 'Position error']

print(tabulate(table, headers, tablefmt="fancy_grid"))
# Out:
# ╒══════════╤═══════════════╤══════════════════╕
# │ Method   │   Shape error │   Position error │
# ╞══════════╪═══════════════╪══════════════════╡
# │ lsm      │       29.1507 │        0.0489497 │
# ├──────────┼───────────────┼──────────────────┤
# │ osm      │       24.5205 │        0.0567433 │
# ├──────────┼───────────────┼──────────────────┤
# │ bim      │       14.9041 │        0.246239  │
# ├──────────┼───────────────┼──────────────────┤
# │ csi      │       26.3288 │        0.314661  │
# ├──────────┼───────────────┼──────────────────┤
# │ som      │       15.4247 │        0.142463  │
# ╘══════════╧═══════════════╧══════════════════╛
