# %% [markdown]
# # Show results

# %%
import sys
sys.path.insert(1, '../../../eispy2d/library/')
import casestudy as cst
import numpy as np
from matplotlib import pyplot as plt
import result as rst
import configuration as cfg

# Read files
N = 5
casestudies = [cst.CaseStudy(import_filename='vary%d.cst' % n,
                             import_filepath='../../../data/shape/vary/') for n in range(N)]
chi = np.array([.25, .5, .75, 1., 1.5])

# %% [markdown]
# ## $\chi = 0.25$

# %%
casestudies[0].reconstruction()
plt.show()

# %% [markdown]
# ## $\chi=0.5$

# %%
casestudies[1].reconstruction()
plt.show()

# %% [markdown]
# ## $\chi=0.75$

# %%
casestudies[2].reconstruction()
plt.show()

# %% [markdown]
# ## $\chi=1$

# %%
casestudies[3].reconstruction()
plt.show()

# %% [markdown]
# ## $\chi=1.5$

# %%
casestudies[4].reconstruction()
plt.show()

# %% [markdown]
# ## Shape error - $\zeta_S$

# %%
error = np.zeros((N, 2))
for n in range(N):
    error[n,0] = casestudies[n].results[0].zeta_s[-1]
    error[n,1] = casestudies[n].results[1].zeta_s[-1]
plt.plot(chi, error, 'o--', linewidth=5, markersize=15, label=['OSM', 'SOM'])
plt.xlabel(r'$\chi$')
plt.ylabel(r'$\zeta_s$ [%]')
plt.legend(loc='upper left')
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## DNL

# %%
dnl = np.zeros(N)
for n in range(N):
    dnl[n] = casestudies[n].test.dnl
plt.plot(chi, dnl, 'o--', linewidth=5, markersize=15)
plt.xlabel(r'$\chi$')
plt.ylabel('DNL')
plt.grid()
plt.tight_layout()
plt.show()
