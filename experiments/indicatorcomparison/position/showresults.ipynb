# %%
import sys
sys.path.insert(1, '../../../eispy2d/library/')
import casestudy as cst
import inputdata as ipt
test = ipt.InputData(import_filename='star.ipt',
                     import_filepath='../../../data/indicatorcomparison/position/')
casestudy = cst.CaseStudy(import_filename='star.cst',
                          import_filepath='../../../data/indicatorcomparison/position/')

# %%
casestudy.reconstruction(fontsize=15, show=True)
test.draw(show=True)

# %%
print(casestudy.results[0])
print(casestudy.results[0].path)
# Out:
# Results name: star.ipt_ca
# Configuration: star.cfg
# Scattered field - measurement samples: 80
# Scattered field - source samples: 80
# Total field - measurement samples: 14400
# Total field - source samples: 80
# Relative Permit. map resolution: 120x120
# Percent. Aver. Devi. of Rel. Permittivity: [17.13%]
# Position error: 0.04%
# Shape error: 46.82%
# SSIM index: 0.8426
# Optimum solution: 5.544155840265709
# [0.34791448 0.35023407 0.36214278 5.54415584]
